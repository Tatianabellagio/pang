# %%
import pandas as pd
# Out:
# /tmp/ipykernel_3634567/4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
seqfile = pd.read_csv('seqfile.txt', sep = '\t',header=None)

# %%
## lets start by creating a pangenome with only a few accessions

# %%
## this are the overlapping ones in between grenent and the 69 pangenomes 
overlap = ['Kar-1',
 'Sus-1',
 'Zal-1',
 'Cvi-0',
 'Ms-0',
 'Can-0',
 'Ct-1',
 'Mh-0',
 'No-0',
 'Oy-0',
 'Rubezhnoe-1',
 'Stw-0',
 'St-0',
 'Altai-5',
 'Anz-0',
 'Qar-8a',
 'Toufl-1',
 'Dog-4']

# %%
len(overlap)
# Out:
# 18

# %%
seqfile_filter = seqfile[seqfile[0].isin(overlap + ['Col-0'])]

# %%
seqfile_filter.to_csv('seqfile.txt', header = None, index=None, sep = '\t')
