# %%
#sshfs tbellagio@calc.carnegiescience.edu:/carnegie/nobackup/scratch/tbellagio/pang /Users/tatiana/Documents_new/pangenomes
# diskutil unmount force /Users/tatiana/Documents_new/pangenomes


sshfs -o reconnect,ServerAliveInterval=15,ServerAliveCountMax=3 \
tbellagio@calc.carnegiescience.edu:/carnegie/nobackup/scratch/tbellagio/pang \
/Users/tatiana/Documents_new/pangenomes

# %%
import pandas as pd
# Out:
# /tmp/ipykernel_3634511/4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
## the first step will be to check how mnay of the accessions we have for grenent are present in the already avilable/soon to be 1001 g projects and how many are not

# %%
pang_69 = pd.read_csv('69_ara_pang/accessions.csv', skiprows=2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 pang_69 = pd.read_csv('69_ara_pang/accessions.csv', skiprows=2)
#
# File /carnegie/hpcdata/software/conda/envs/python-3.11/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1024, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1011 kwds_defaults = _refine_defaults_read(
#    1012     dialect,
#    1013     delimiter,
#    (...)
#    1020     dtype_backend=dtype_backend,
#    1021 )
#    1022 kwds.update(kwds_defaults)
# -> 1024 return _read(filepath_or_buffer, kwds)
#
# File /carnegie/hpcdata/software/conda/envs/python-3.11/lib/python3.11/site-packages/pandas/io/parsers/readers.py:618, in _read(filepath_or_buffer, kwds)
#     615 _validate_names(kwds.get("names", None))
#     617 # Create the parser.
# --> 618 parser = TextFileReader(filepath_or_buffer, **kwds)
#     620 if chunksize or iterator:
#     621     return parser
#
# File /carnegie/hpcdata/software/conda/envs/python-3.11/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1618, in TextFileReader.__init__(self, f, engine, **kwds)
#    1615     self.options["has_index_names"] = kwds["has_index_names"]
#    1617 self.handles: IOHandles | None = None
# -> 1618 self._engine = self._make_engine(f, self.engine)
#
# File /carnegie/hpcdata/software/conda/envs/python-3.11/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1878, in TextFileReader._make_engine(self, f, engine)
#    1876     if "b" not in mode:
#    1877         mode += "b"
# -> 1878 self.handles = get_handle(
#    1879     f,
#    1880     mode,
#    1881     encoding=self.options.get("encoding", None),
#    1882     compression=self.options.get("compression", None),
#    1883     memory_map=self.options.get("memory_map", False),
#    1884     is_text=is_text,
#    1885     errors=self.options.get("encoding_errors", "strict"),
#    1886     storage_options=self.options.get("storage_options", None),
#    1887 )
#    1888 assert self.handles is not None
#    1889 f = self.handles.handle
#
# File /carnegie/hpcdata/software/conda/envs/python-3.11/lib/python3.11/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '69_ara_pang/accessions.csv'

# %%
pang_23 = pd.read_csv('23_ara_pang/accessions.csv')

# %%
lr_1001= pd.read_csv('long_read_seq_ara/Athaliana_assembly_IDs_OVERVIEW.csv',dtype=str)

# %%
grenenet = pd.read_csv('long_read_seq_ara/grene_ecotypes.csv')[['ID', 'name', 'country']]
grenenet = grenenet.dropna()
grenenet['acc_ID'] = grenenet['ID'].astype(int)

# %%
accessions = pd.read_csv('1001g_accesions_list.csv',header=None )

# %%
new_columns = [
    "acc_ID",
    "seq_by",
    "name",
    "country",
    "name_2",
    "lat",
    "lon",
    "collector",
    "date",
    "cs_number",
    "admixture_group",
    "unknown",
    "unknown2"
]

accessions.columns = new_columns

# %%
accessions.head()
# Out:
#    acc_ID    seq_by    name country name_2      lat       lon  \
# 0      88  Monsanto     CYR     FRA    CYR  47.4000  0.683333
# 1     108  Monsanto  LDV-18     FRA    LDV  48.5167 -4.066670
# 2     139  Monsanto  LDV-46     FRA    LDV  48.5167 -4.066670
# 3     159  Monsanto  MAR2-3     FRA   Mar2  47.3500  3.933330
# 4     265  Monsanto   PYL-6     FRA    PYL  44.6500 -1.166670
#
#           collector date cs_number admixture_group unknown    unknown2
# 0  Valerie Le Corre  NaN   CS76790  western_europe     NaN  blu_circle
# 1  Valerie Le Corre  NaN   CS77013  western_europe     NaN  blu_circle
# 2  Valerie Le Corre  NaN   CS77014  western_europe     NaN  blu_circle
# 3  Valerie Le Corre  NaN   CS77070  western_europe     NaN  blu_circle
# 4  Valerie Le Corre  NaN   CS77198         admixed     NaN   forbidden

# %%
## acc_ID 225 matches 
##  acc_ID + name 200 matches    ## tshisseem to be typos 
##  acc_ID + name + country 199 matches  ## ther eis one acession but i guess it is unsure if it estoniaor germany 
grenenet_accession = grenenet.merge(accessions, on = ['acc_ID'], how = 'left', suffixes=('_grene','_1001'))
grenenet_accession.drop(columns=['ID'],inplace=True)

# %%
grenenet_accession.to_csv('grenenet_accessions.csv',index=False)

# %%
## teh ones that were not found in the 1001g from greneet 
grenenet_accession[grenenet_accession['seq_by'].isna()]
# Out:
#      name_grene country_grene  acc_ID seq_by name_1001 country_1001 name_2  \
# 35         Mt-0           LIB    6939    NaN       NaN          NaN    NaN
# 214     Toufl-1           MAR    9940    NaN       NaN          NaN    NaN
# 220  Vezzano2-1           ITA    9977    NaN       NaN          NaN    NaN
# 223       Dog-4           TUR    9992    NaN       NaN          NaN    NaN
# 229   Ziv-24208           ISR  100001    NaN       NaN          NaN    NaN
# 230        Her-           ISR  100002    NaN       NaN          NaN    NaN
#
#      lat  lon collector date cs_number admixture_group unknown unknown2
# 35   NaN  NaN       NaN  NaN       NaN             NaN     NaN      NaN
# 214  NaN  NaN       NaN  NaN       NaN             NaN     NaN      NaN
# 220  NaN  NaN       NaN  NaN       NaN             NaN     NaN      NaN
# 223  NaN  NaN       NaN  NaN       NaN             NaN     NaN      NaN
# 229  NaN  NaN       NaN  NaN       NaN             NaN     NaN      NaN
# 230  NaN  NaN       NaN  NaN       NaN             NaN     NaN      NaN

# %%
## delete the F1 (Col-0/Cvi-0)
lr_1001 = lr_1001[lr_1001['Accession_Name'] != 'F1 (Col-0/Cvi-0)']

# %%
lr_1001.drop(columns=['QC_pipeline', 'Final_assembly', 'TMP_comments' ],inplace=True)

# %%
lr_1001.rename(columns={'Accession_ID': 'acc_ID'}, inplace=True)
lr_1001['acc_ID'] = lr_1001['acc_ID'].astype(int)

# %%
# Convert Latitude/Longitude safely
lr_1001['Latitude'] = pd.to_numeric(lr_1001['Latitude'], errors='coerce')
lr_1001['Longitude'] = pd.to_numeric(lr_1001['Longitude'], errors='coerce')

# %%
def extract_float(x):
    if pd.isna(x):
        return np.nan
    # Try direct float
    try:
        return float(x)
    except:
        pass
    # Extract potential float inside a messy string (e.g date)
    import re
    match = re.search(r"-?\d+\.\d+", str(x))
    if match:
        return float(match.group())
    return np.nan

lr_1001['Latitude'] = lr_1001['Latitude'].apply(extract_float)
lr_1001['Longitude'] = lr_1001['Longitude'].apply(extract_float)

# %%
lr_1001
# Out:
#     Assembly_ID Accession_Name  acc_ID   Accession_alias Original_Assembly_ID  \
# 0        100000          Col-0    6909            TAIR10                  NaN
# 1        100001          Col-0    6909  TAIR12 version 1             100001.0
# 2        100002          Col-0    6909  TAIR12 version 2             100001.0
# 3        100003          Ler-0    7213               NaN                  NaN
# 5        100005          Ler-0    7213               NaN                  NaN
# ..          ...            ...     ...               ...                  ...
# 425      100425     UKSW06-240    4840               NaN                  NaN
# 426      100426     UKSE06-541    5279               NaN                  NaN
# 427      100427          Yeg-7    9133               NaN                  NaN
# 428      100428          Yeg-8    9134               NaN                  NaN
# 429      100429           Zu-0    7417               NaN                  NaN
#
#     Version CSnumber  Latitude  Longitude Altitude  ...          Assembler  \
# 0       1.0      NaN       NaN        NaN      NaN  ...                NaN
# 1       1.0      NaN       NaN        NaN      NaN  ...                NaN
# 2       2.0      NaN       NaN        NaN      NaN  ...                NaN
# 3       NaN      NaN       NaN        NaN      NaN  ...                NaN
# 5       1.0      NaN       NaN        NaN      NaN  ...                NaN
# ..      ...      ...       ...        ...      ...  ...                ...
# 425     1.0  CS79000        50         -5      NaN  ...    Flye_v2.9-b1768
# 426     1.0  CS79004        51        NaN      NaN  ...  nextDenovo_v2.5.0
# 427     1.0  CS78867        40         45      NaN  ...    Flye_v2.9-b1768
# 428     1.0  CS78868        40         45      NaN  ...    Flye_v2.9-b1768
# 429     1.0  CS78880        47          9      NaN  ...  nextDenovo_v2.5.0
#
#     Individual_or_pool Latest_released_Year Published  \
# 0                 Pool                  NaN       yes
# 1                 Pool               2023.0        no
# 2                 Pool               2023.0        no
# 3                  NaN                  NaN       yes
# 5                 Pool               2016.0       yes
# ..                 ...                  ...       ...
# 425                NaN               2024.0        no
# 426                NaN               2024.0        no
# 427                NaN               2024.0        no
# 428                NaN               2024.0        no
# 429                NaN               2024.0        no
#
#     Publication_First_author Publication_year Publication_Journal  \
# 0                        NaN              NaN                 NaN
# 1                       TAIR              NaN         unpublished
# 2                       TAIR              NaN         unpublished
# 3                     Berlin           2015.0       NatBiotechnol
# 5                     Zapata           2016.0                PNAS
# ..                       ...              ...                 ...
# 425                      NaN              NaN         unpublished
# 426                      NaN              NaN         unpublished
# 427                      NaN              NaN         unpublished
# 428                      NaN              NaN         unpublished
# 429                      NaN              NaN         unpublished
#
#              Publication_DOI  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3           10.1038/nbt.3238
# 5    10.1073/pnas.1607532113
# ..                       ...
# 425                      NaN
# 426                      NaN
# 427                      NaN
# 428                      NaN
# 429                      NaN
#
#                                        Publication_URL Best_unique_assembly
# 0                                                  NaN                  0.0
# 1                                                  NaN                  0.0
# 2                                                  NaN                  1.0
# 3             https://www.nature.com/articles/nbt.3238                  NaN
# 5    https://www.pnas.org/doi/full/10.1073/pnas.160...                  NaN
# ..                                                 ...                  ...
# 425                                                NaN                  NaN
# 426                                                NaN                  NaN
# 427                                                NaN                  NaN
# 428                                                NaN                  NaN
# 429                                                NaN                  NaN
#
# [429 rows x 25 columns]

# %%
print(len(grenenet_accession.merge(lr_1001, on = 'acc_ID', how = 'inner')))
print(len(grenenet_accession.merge(lr_1001, on = 'acc_ID', how = 'left')))
# Out:
# 79
# 250

# %%
pang23_names_1001 = set(pang_23['Name'])
pang69_names_grene = set(pang_69['Accession'])
lr_ids = set(lr_1001['acc_ID'])

grenenet_accession['in_pang23'] = grenenet_accession['name_grene'].isin(pang23_names_1001)
grenenet_accession['in_pang69'] = grenenet_accession['name_grene'].isin(pang69_names_grene)
grenenet_accession['in_longreads'] = grenenet_accession['acc_ID'].isin(lr_ids)

# %%
grenenet_accession[['in_pang23', 'in_pang69', 'in_longreads']].value_counts()
# Out:
# in_pang23  in_pang69  in_longreads
# False      False      False           171
#                       True             39
#            True       True             16
# True       False      True              3
#            True       True              2
# Name: count, dtype: int64

# %%
pang_69
# Out:
#    Accession Acc_ID     Country Latitude Longitude Long-read technology  \
# 0       Db-1  132AV     Germany    50.28      8.36          Pacbio HiFi
# 1      Est-0   71AV     Estonia    59.45     24.76          Pacbio HiFi
# 2      Kas-1  108AV       India     34.2     76.83          Pacbio HiFi
# 3       Lu-1   54AV      Sweden    55.72     13.19          Pacbio HiFi
# 4       Mh-0  175AV      Poland    52.24     21.01          Pacbio HiFi
# ..       ...    ...         ...      ...       ...                  ...
# 67      Ri-0  160AV      Canada    49.18   -123.13      Oxford Nanopore
# 68  Shahdara  236AV  Tajikistan    38.59     68.79      Oxford Nanopore
# 69   Shigu-2  650AV      Russia    53.33     49.48      Oxford Nanopore
# 70     Tsu-0   91AV       Japan    34.73    136.50      Oxford Nanopore
# 71      Yo-0  250AV         USA    37.75   -119.58      Oxford Nanopore
#
#     Long-read size (Gb)  Long-read (N50, bp)  Long-read depths  \
# 0                  6.56                15504                52
# 1                  4.37                14876                34
# 2                  4.17                15807                33
# 3                  9.22                17516                73
# 4                  8.53                16640                67
# ..                  ...                  ...               ...
# 67                 6.85                27110                54
# 68                 6.88                23924                54
# 69                 7.74                22955                61
# 70                11.92                26082                94
# 71                 8.22                25858                65
#
#     Short-read depths
# 0                  30
# 1                  31
# 2                  28
# 3                  31
# 4                  32
# ..                ...
# 67                 81
# 68                 69
# 69                 85
# 70                 55
# 71                 61
#
# [72 rows x 10 columns]

# %%
grenenet_accession.merge(pang_69, right_on = 'Accession', left_on = 'name_grene', how = 'inner')
# Out:
#      name_grene country_grene  acc_ID seq_by    name_1001 country_1001  \
# 0         Kar-1           KGZ     763   Salk        Kar-1          KGZ
# 1         Sus-1           KGZ     765   Salk        Sus-1          KGZ
# 2         Zal-1           KGZ     768   Salk        Zal-1          KGZ
# 3         Cvi-0           CPV    6911   Salk        Cvi-0          CPV
# 4          Ms-0           RUS    6938   Salk         Ms-0          RUS
# 5         Can-0           ESP    7063   Mott        Can-0          ESP
# 6          Ct-1           ITA    7067   Mott         Ct-1          ITA
# 7          Mh-0           POL    7255   Salk         Mh-0          POL
# 8          No-0           GER    7273   Mott         No-0          GER
# 9          Oy-0           NOR    7288   Mott         Oy-0          NOR
# 10  Rubezhnoe-1           UKR    7323   Salk  Rubezhnoe-1          UKR
# 11        Stw-0           RUS    7347   Salk        Stw-0          RUS
# 12         St-0           SWE    8387    GMI         St-0          SWE
# 13      Altai-5           CHN    9758   Salk      Altai-5          CHN
# 14        Anz-0           IRN    9759   Salk        Anz-0          IRN
# 15       Qar-8a           LBN    9764   Salk       Qar-8a          LBN
# 16      Toufl-1           MAR    9940    NaN          NaN          NaN
# 17        Dog-4           TUR    9992    NaN          NaN          NaN
#
#        name_2        lat        lon       collector  ...    Accession Acc_ID  \
# 0     Karakol  42.300000  74.366700  Olivier Loudet  ...        Kar-1  531AV
# 1     Susamyr  42.183300  73.400000  Olivier Loudet  ...        Sus-1  533AV
# 2     Zalisky  42.800000  76.350000  Olivier Loudet  ...        Zal-1  536AV
# 3         Cvi  15.111100 -23.616700    Albert Kranz  ...        Cvi-0  166AV
# 4          Ms  55.752200  37.632200    Albert Kranz  ...         Ms-0   93AV
# 5         Can  29.214400 -13.481100    Albert Kranz  ...        Can-0  163AV
# 6          Ct  37.300000  15.000000    Albert Kranz  ...         Ct-1  162AV
# 7      Muhlen  50.950000  20.500000    Albert Kranz  ...         Mh-0  175AV
# 8       Halle  51.058100  13.299500    Albert Kranz  ...         No-0   49AV
# 9          Oy  60.385543   6.193019    Albert Kranz  ...         Oy-0  224AV
# 10  Rubezhnoe  49.000000  38.280000      Igor Vizir  ...  Rubezhnoe-1  231AV
# 11        Stw  52.000000  36.000000    Albert Kranz  ...        Stw-0   92AV
# 12         St  62.879400  18.447300    Albert Kranz  ...         St-0   62AV
# 13        NaN  47.750000  88.400000               0  ...      Altai-5  548AV
# 14        NaN  37.470000  49.470000               0  ...        Anz-0  704AV
# 15        NaN  34.100000  35.840000               0  ...       Qar-8a  549AV
# 16        NaN        NaN        NaN             NaN  ...      Toufl-1  646AV
# 17        NaN        NaN        NaN             NaN  ...        Dog-4  581AV
#
#        Country Latitude Longitude  Long-read technology  Long-read size (Gb)  \
# 0   Kyrgyzstan     42.3     74.37           Pacbio HiFi                 5.73
# 1   Kyrgyzstan    42.19     73.41           Pacbio HiFi                 5.43
# 2   Kyrgyzstan     42.8     76.35           Pacbio HiFi                 3.81
# 3     Portugal    15.06    -23.73       Oxford Nanopore                10.12
# 4       Russia    55.78     37.62           Pacbio HiFi                 4.12
# 5        Spain    29.21    -13.48       Oxford Nanopore                 7.72
# 6        Italy    37.51     15.09       Oxford Nanopore                 8.34
# 7       Poland    52.24     21.01           Pacbio HiFi                 8.53
# 8      Germany    51.07      13.3           Pacbio HiFi                 4.22
# 9       Norway    60.39      6.19       Oxford Nanopore                 5.40
# 10     Ukraine    50.47     30.52           Pacbio HiFi                 4.72
# 11      Russia    52.84     36.92           Pacbio HiFi                 4.91
# 12      Sweden    59.34     18.06           Pacbio HiFi                 6.35
# 13       China    47.76      88.4           Pacbio HiFi                 6.02
# 14        Iran    37.50     49.37           Pacbio HiFi                 6.49
# 15     Lebanon     34.1     35.84           Pacbio HiFi                 4.47
# 16     Morocco    31.47     -7.42           Pacbio HiFi                 5.49
# 17      Turkey    38.30     42.22           Pacbio HiFi                 4.58
#
#     Long-read (N50, bp) Long-read depths Short-read depths
# 0                 18353               45                31
# 1                 15699               43                27
# 2                 16279               30                28
# 3                 25729               80                61
# 4                 17230               32                29
# 5                 25666               61                58
# 6                 25191               66                85
# 7                 16640               67                32
# 8                 15558               33                29
# 9                 22492               42                68
# 10                15594               37                32
# 11                16830               39                30
# 12                15557               50                30
# 13                14936               47                31
# 14                17160               51                29
# 15                16050               35                32
# 16                18477               43                26
# 17                15889               36                30
#
# [18 rows x 28 columns]

# %%
#grenenet_accession.merge(pang_23, right_on = 'Name', left_on = 'name_grene', how = 'inner')
#grenenet_accession.merge(pang_23, right_on = 'Name', left_on = 'namename_grene_1001', how = 'inner')

# %%
from matplotlib import pyplot as plt
from matplotlib_venn import venn3

# Boolean columns
set23 = set(grenenet_accession[grenenet_accession['in_pang23'] == True]['acc_ID'])
set69 = set(grenenet_accession[grenenet_accession['in_pang69'] == True]['acc_ID'])
setLR = set(grenenet_accession[grenenet_accession['in_longreads'] == True]['acc_ID'])

plt.figure(figsize=(7,7))
venn3([set23, set69, setLR],
      set_labels=('pang23', 'pang69', 'Long-read'))
plt.title("Overlap of GrENE-net Accessions Across Datasets")
plt.show()

# %%
len(grenenet_accession[(grenenet_accession['in_longreads'] == True)])
# Out:
# 60

# %%
grenenet_accession
# Out:
#     name_grene country_grene  acc_ID    seq_by name_1001 country_1001  \
# 0       MAR2-3           FRA     159  Monsanto    MAR2-3          FRA
# 1        PYL-6           FRA     265  Monsanto     PYL-6          FRA
# 2        Kar-1           KGZ     763      Salk     Kar-1          KGZ
# 3        Sus-1           KGZ     765      Salk     Sus-1          KGZ
# 4        Dja-1           KGZ     766      Salk     Dja-1          KGZ
# ..         ...           ...     ...       ...       ...          ...
# 226      Yeg-1           ARM   10011       MPI     Yeg-1          ARM
# 227   Lerik1-3           AZE   10013       MPI  Lerik1-3          AZE
# 228      Xan-1           AZE   10014       MPI     Xan-1          AZE
# 229  Ziv-24208           ISR  100001       NaN       NaN          NaN
# 230       Her-           ISR  100002       NaN       NaN          NaN
#
#        name_2  lat  lon         collector                date cs_number  \
# 0        Mar2   47    4  Valerie Le Corre                 NaN   CS77070
# 1         PYL   45   -1  Valerie Le Corre                 NaN   CS77198
# 2     Karakol   42   74    Olivier Loudet  2004-07-03 0:00:00   CS76522
# 3     Susamyr   42   73    Olivier Loudet  2004-07-04 0:00:00   CS76607
# 4      Djarly   43   74    Olivier Loudet  2004-07-07 0:00:00   CS76473
# ..        ...  ...  ...               ...                 ...       ...
# 226  Yeghegis   40   45        James Beck  1999-12-30 0:00:00   CS76394
# 227     Lerik   39   49        James Beck                 NaN   CS76388
# 228  Xanbulan   39   49        James Beck  1999-12-30 0:00:00   CS76387
# 229       NaN  NaN  NaN               NaN                 NaN       NaN
# 230       NaN  NaN  NaN               NaN                 NaN       NaN
#
#            admixture_group unknown       unknown2  in_pang23  in_pang69  \
# 0           western_europe     NaN     blu_circle      False      False
# 1                  admixed     NaN      forbidden      False      False
# 2                     asia     NaN  purple_circle      False       True
# 3                     asia     NaN  purple_circle      False       True
# 4                     asia     NaN  purple_circle      False      False
# ..                     ...     ...            ...        ...        ...
# 226                   asia     NaN  purple_circle      False      False
# 227  italy_balkan_caucasus     NaN     wht_circle      False      False
# 228  italy_balkan_caucasus     NaN     wht_circle      False      False
# 229                    NaN     NaN            NaN      False      False
# 230                    NaN     NaN            NaN      False      False
#
#      in_longreads
# 0            True
# 1           False
# 2            True
# 3            True
# 4           False
# ..            ...
# 226         False
# 227         False
# 228         False
# 229         False
# 230          True
#
# [231 rows x 18 columns]

# %%
grenenet_accession[(grenenet_accession['in_longreads'] == True)] #[['name_grene',	'country_grene',	'acc_ID']] #.to_csv('overlap_grenenet_lra.csv',index=False)
# Out:
#       name_grene country_grene  acc_ID    seq_by    name_1001 country_1001  \
# 0         MAR2-3           FRA     159  Monsanto       MAR2-3          FRA
# 2          Kar-1           KGZ     763      Salk        Kar-1          KGZ
# 3          Sus-1           KGZ     765      Salk        Sus-1          KGZ
# 5          Zal-1           KGZ     768      Salk        Zal-1          KGZ
# 6          Neo-6           TJK     772      Salk        Neo-6          TJK
# 11          Ty-1            UK    5784  Monsanto         Ty-1           UK
# 28        TRA 01           SWE    6244       GMI      TRÃ 01          SWE
# 29          An-1           BEL    6898      Salk         An-1          BEL
# 30         Cvi-0           CPV    6911      Salk        Cvi-0          CPV
# 31          Ei-2           GER    6915      Salk         Ei-2          GER
# 32       Kondara           TJK    6929      Salk      Kondara          TJK
# 33         Ler-1           GER    6932   MPI,GMI        Ler-1          GER
# 34          Ms-0           RUS    6938      Salk         Ms-0          RUS
# 35          Mt-0           LIB    6939       NaN          NaN          NaN
# 37         Nok-3           NED    6945      Salk        Nok-3          NED
# 40         Sorbo           TJK    6963      Salk        Sorbo          TJK
# 43          Aa-0           GER    7000      Salk         Aa-0          GER
# 44         Baa-1           NED    7002      Salk        Baa-1          NED
# 45          Bs-1           SUI    7003      Salk         Bs-1          SUI
# 48          Bl-1           ITA    7025      Salk         Bl-1          ITA
# 53         Can-0           ESP    7063      Mott        Can-0          ESP
# 54          Ct-1           ITA    7067      Mott         Ct-1          ITA
# 57         Com-1           FRA    7092      Salk        Com-1          FRA
# 62           Est           GER    7127      Salk          Est          EST
# 63         Gel-1           NED    7143      Salk        Gel-1          NED
# 66          Kn-0           LTU    7186      Mott         Kn-0          LTU
# 72          Mh-0           POL    7255      Salk         Mh-0          POL
# 74          No-0           GER    7273      Mott         No-0          GER
# 78          Oy-0           NOR    7288      Mott         Oy-0          NOR
# 80          Pi-0           AUT    7298      Salk         Pi-0          AUT
# 82   Rubezhnoe-1           UKR    7323      Salk  Rubezhnoe-1          UKR
# 84         Ste-0           GER    7346  Monsanto       Sten-0          GER
# 85         Stw-0           RUS    7347      Salk        Stw-0          RUS
# 87       Tscha-1           AUT    7372      Salk      Tscha-1          AUT
# 88          Uk-1           GER    7378      Salk         Uk-1          GER
# 103        Per-1           RUS    8354      Salk        Per-1          RUS
# 106         St-0           SWE    8387       GMI         St-0          SWE
# 112        Kru-3           SWE    9416       GMI        Kru-3          SWE
# 114        Tur-4           SWE    9470       GMI        Tur-4          SWE
# 116     IP-Alo-0           POR    9506  Monsanto     IP-Alo-0          POR
# 121     IP-Alm-0           ESP    9518  Monsanto     IP-Alm-0          ESP
# 132     IP-Cum-1           ESP    9537  Monsanto     IP-Cum-1          ESP
# 134     IP-Fun-0           ESP    9542  Monsanto     IP-Fun-0          ESP
# 138     IP-Hum-2           ESP    9549  Monsanto     IP-Hum-2          ESP
# 139     IP-Mar-1           ESP    9555  Monsanto     IP-Mar-1          ESP
# 140     IP-Moa-0           ESP    9557  Monsanto     IP-Moa-0          ESP
# 144    IP-Nog-17           ESP    9564  Monsanto    IP-Nog-17          ESP
# 153     IP-Vdm-0           ESP    9594  Monsanto     IP-Vdm-0          ESP
# 158     IP-Vis-0           ESP    9600  Monsanto     IP-Vis-0          ESP
# 189      Altai-5           CHN    9758      Salk      Altai-5          CHN
# 190        Anz-0           IRN    9759      Salk        Anz-0          IRN
# 192       Qar-8a           LBN    9764      Salk       Qar-8a          LBN
# 206        Con-0           ESP    9837  Monsanto     IP-Con-0          ESP
# 208        Per-0           ESP    9879  Monsanto     IP-Per-0          ESP
# 209        BRI-2           FRA    9910  Monsanto        BRI-2          FRA
# 214      Toufl-1           MAR    9940       NaN          NaN          NaN
# 217        Ped-0           ESP    9947       MPI        Ped-0          ESP
# 223        Dog-4           TUR    9992       NaN          NaN          NaN
# 224     TueWa1-2           GER   10002       MPI     TueWa1-2          GER
# 230         Her-           ISR  100002       NaN          NaN          NaN
#
#                name_2  lat  lon             collector                date  \
# 0                Mar2   47    4      Valerie Le Corre                 NaN
# 2             Karakol   42   74        Olivier Loudet  2004-07-03 0:00:00
# 3             Susamyr   42   73        Olivier Loudet  2004-07-04 0:00:00
# 5             Zalisky   43   76        Olivier Loudet  2004-07-18 0:00:00
# 6        Neo-Shahdara   37   72        Olivier Loudet  2004-07-25 0:00:00
# 11           Taynuilt   56   -5          D. Ratcliffe  1961-01-01 0:00:00
# 28               TRÃ   56   14     Mattias Jakobsson  2003-01-01 0:00:00
# 29                 An   51    4          Albert Kranz                 NaN
# 30                Cvi   15  -24          Albert Kranz                 NaN
# 31              Eifel   50    6          Albert Kranz                 NaN
# 32            Kondara   38   68            Igor Vizir                 NaN
# 33                Ler   48   11            Eric Holub                 NaN
# 34                 Ms   56   38          Albert Kranz                 NaN
# 35                NaN  NaN  NaN                   NaN                 NaN
# 37                Nok   52    4          Albert Kranz                 NaN
# 40              Sorbo   38   68            Igor Vizir                 NaN
# 43           Aua/Rhon   51   10          Albert Kranz                 NaN
# 44                Baa   51    6     Maarten Koornneef                 NaN
# 45                 Bs   48    8          Albert Kranz                 NaN
# 48                 Bl   45   11          Albert Kranz                 NaN
# 53                Can   29  -13          Albert Kranz                 NaN
# 54                 Ct   37   15          Albert Kranz                 NaN
# 57                Com   49    3     Maarten Koornneef                 NaN
# 62             EstGER   59   25         Brigitte Damm                 NaN
# 63                Gel   51    6     Maarten Koornneef                 NaN
# 66                 Kn   55   24          Albert Kranz                 NaN
# 72             Muhlen   51   20          Albert Kranz                 NaN
# 74              Halle   51   13          Albert Kranz                 NaN
# 78                 Oy   60    6          Albert Kranz  2002-05-24 2:00:00
# 80                 Pi   47   11          Albert Kranz                 NaN
# 82          Rubezhnoe   49   38            Igor Vizir                 NaN
# 84            Stendal   53   12          Albert Kranz                 NaN
# 85                Stw   52   36          Albert Kranz                 NaN
# 87              Tscha   47   10     Maarten Koornneef                 NaN
# 88            Umkirch   48    8          Albert Kranz                 NaN
# 103               Per   58   56          Albert Kranz                 NaN
# 106                St   63   18          Albert Kranz                 NaN
# 112  KrusmyntagÃ¥rden   57   18      Alison Anastasio                 NaN
# 114          Turlunda   56   13      Alison Anastasio                 NaN
# 116               NaN   40   -7  Carlos Alonso-Blanco          00/01/2007
# 121               NaN   40   -0  Carlos Alonso-Blanco  2004-12-31 0:00:00
# 132               NaN   38   -7  Carlos Alonso-Blanco          00/01/2002
# 134               NaN   41   -4  Carlos Alonso-Blanco  2005-12-31 0:00:00
# 138               NaN   42   -4  Carlos Alonso-Blanco  2006-12-31 0:00:00
# 139               NaN   40   -4  Carlos Alonso-Blanco  2003-12-31 0:00:00
# 140               NaN   42    1  Carlos Alonso-Blanco          00/01/2004
# 144               NaN   40   -2          Xavier PicÃ³          00/01/2004
# 153               NaN   42    1  Carlos Alonso-Blanco          00/01/2006
# 158               NaN   40   -6  Carlos Alonso-Blanco  2005-12-31 0:00:00
# 189               NaN   48   88                     0            12/30/99
# 190               NaN   37   49                     0            12/30/99
# 192               NaN   34   36                     0  1999-12-30 0:00:00
# 206       Constantina   38   -6          Xavier PicÃ³  1999-12-30 0:00:00
# 208            PerÃ­n   38   -1  Carlos Alonso-Blanco  1999-12-30 0:00:00
# 209               NaN   51    4                     0            12/30/99
# 214               NaN  NaN  NaN                   NaN                 NaN
# 217               NaN   41   -4                   NaN  1999-12-30 0:00:00
# 223               NaN  NaN  NaN                   NaN                 NaN
# 224  Tubingen - Wanne   49    9      Kirsten Bomblies  1999-12-30 0:00:00
# 230               NaN  NaN  NaN                   NaN                 NaN
#
#     cs_number        admixture_group unknown       unknown2  in_pang23  \
# 0     CS77070         western_europe     NaN     blu_circle      False
# 2     CS76522                   asia     NaN  purple_circle      False
# 3     CS76607                   asia     NaN  purple_circle      False
# 5     CS76634                   asia     NaN  purple_circle      False
# 6     CS76560                   asia     NaN  purple_circle      False
# 11    CS78790                admixed     NaN      forbidden      False
# 28    CS77384           north_sweden     NaN  orange_circle      False
# 29    CS76435                admixed     NaN      forbidden      False
# 30    CS76789                 relict       Y     grn_circle      False
# 31    CS76478                germany     NaN   ltblu_circle      False
# 32    CS76532                   asia     NaN  purple_circle       True
# 33    CS77021                admixed     NaN      forbidden      False
# 34    CS76555                   asia     NaN  purple_circle       True
# 35        NaN                    NaN     NaN            NaN      False
# 37    CS76562                germany     NaN   ltblu_circle      False
# 40    CS78917                   asia     NaN  purple_circle       True
# 43    CS76428                germany     NaN   ltblu_circle      False
# 44    CS76442                germany     NaN   ltblu_circle      False
# 45    CS78888                admixed     NaN      forbidden      False
# 48    CS76450         central_europe     NaN     ylw_circle      False
# 53    CS76740                 relict       Y     grn_circle      False
# 54    CS76786         central_europe     NaN     ylw_circle      False
# 57    CS76469         western_europe     NaN     blu_circle      False
# 62    CS76485                admixed     NaN      forbidden      False
# 63    CS76492                germany     NaN   ltblu_circle      False
# 66    CS76969         central_europe     NaN     ylw_circle      False
# 72    CS76550                germany     NaN   ltblu_circle      False
# 74    CS77128         central_europe     NaN     ylw_circle      False
# 78    CS77156                admixed     NaN      forbidden      False
# 80    CS76572         central_europe     NaN     ylw_circle      False
# 82    CS76594                   asia     NaN  purple_circle      False
# 84    CS77277           south_sweden     NaN     red_circle      False
# 85    CS76605         central_europe     NaN     ylw_circle      False
# 87    CS76616         central_europe     NaN     ylw_circle      False
# 88    CS76620                admixed     NaN      forbidden      False
# 103   CS76571                   asia     NaN  purple_circle       True
# 106   CS77270                germany     NaN   ltblu_circle       True
# 112   CS76986           south_sweden     NaN     red_circle      False
# 114   CS77399           south_sweden     NaN     red_circle      False
# 116   CS76662                admixed     NaN      forbidden      False
# 121   CS76660                  spain       Y    pink_circle      False
# 132   CS76787                  spain     NaN    pink_circle      False
# 134   CS76872                 relict       Y     grn_circle      False
# 138   CS76943                 relict       Y     grn_circle      False
# 139   CS77068                 relict       Y     grn_circle      False
# 140   CS77102                  spain     NaN    pink_circle      False
# 144   CS77129                  spain     NaN    pink_circle      False
# 153   CS78837                  spain     NaN    pink_circle      False
# 158   CS78848                 relict       Y     grn_circle      False
# 189   CS76433                   asia     NaN  purple_circle      False
# 190   CS76439  italy_balkan_caucasus     NaN     wht_circle      False
# 192   CS76581                admixed       Y      forbidden      False
# 206   CS76780                 relict       Y     grn_circle      False
# 208   CS77169                 relict       Y     grn_circle      False
# 209   CS76725         western_europe     NaN     blu_circle      False
# 214       NaN                    NaN     NaN            NaN      False
# 217   CS76415                 relict       Y     grn_circle      False
# 223       NaN                    NaN     NaN            NaN      False
# 224   CS76405         western_europe     NaN     blu_circle      False
# 230       NaN                    NaN     NaN            NaN      False
#
#      in_pang69  in_longreads
# 0        False          True
# 2         True          True
# 3         True          True
# 5         True          True
# 6        False          True
# 11       False          True
# 28       False          True
# 29       False          True
# 30        True          True
# 31       False          True
# 32       False          True
# 33       False          True
# 34        True          True
# 35       False          True
# 37       False          True
# 40       False          True
# 43       False          True
# 44       False          True
# 45       False          True
# 48       False          True
# 53        True          True
# 54        True          True
# 57       False          True
# 62       False          True
# 63       False          True
# 66       False          True
# 72        True          True
# 74        True          True
# 78        True          True
# 80       False          True
# 82        True          True
# 84       False          True
# 85        True          True
# 87       False          True
# 88       False          True
# 103      False          True
# 106       True          True
# 112      False          True
# 114      False          True
# 116      False          True
# 121      False          True
# 132      False          True
# 134      False          True
# 138      False          True
# 139      False          True
# 140      False          True
# 144      False          True
# 153      False          True
# 158      False          True
# 189       True          True
# 190       True          True
# 192       True          True
# 206      False          True
# 208      False          True
# 209      False          True
# 214       True          True
# 217      False          True
# 223       True          True
# 224      False          True
# 230      False          True

# %%
grenenet_accession[(grenenet_accession['in_longreads'] == False) & (grenenet_accession['in_pang23'] == True)]
# Out:
# Empty DataFrame
# Columns: [name_grene, country_grene, acc_ID, seq_by, name_1001, country_1001, name_2, lat, lon, collector, date, cs_number, admixture_group, unknown, unknown2, in_pang23, in_pang69, in_longreads]
# Index: []

# %%
grenenet_accession[(grenenet_accession['in_longreads'] == False) & (grenenet_accession['in_pang69'] == True)]
# Out:
# Empty DataFrame
# Columns: [name_grene, country_grene, acc_ID, seq_by, name_1001, country_1001, name_2, lat, lon, collector, date, cs_number, admixture_group, unknown, unknown2, in_pang23, in_pang69, in_longreads]
# Index: []

# %%
grenenet_accession
# Out:
#     name_grene country_grene  acc_ID    seq_by name_1001 country_1001  \
# 0       MAR2-3           FRA     159  Monsanto    MAR2-3          FRA
# 1        PYL-6           FRA     265  Monsanto     PYL-6          FRA
# 2        Kar-1           KGZ     763      Salk     Kar-1          KGZ
# 3        Sus-1           KGZ     765      Salk     Sus-1          KGZ
# 4        Dja-1           KGZ     766      Salk     Dja-1          KGZ
# ..         ...           ...     ...       ...       ...          ...
# 226      Yeg-1           ARM   10011       MPI     Yeg-1          ARM
# 227   Lerik1-3           AZE   10013       MPI  Lerik1-3          AZE
# 228      Xan-1           AZE   10014       MPI     Xan-1          AZE
# 229  Ziv-24208           ISR  100001       NaN       NaN          NaN
# 230       Her-           ISR  100002       NaN       NaN          NaN
#
#        name_2  lat  lon         collector                date cs_number  \
# 0        Mar2   47    4  Valerie Le Corre                 NaN   CS77070
# 1         PYL   45   -1  Valerie Le Corre                 NaN   CS77198
# 2     Karakol   42   74    Olivier Loudet  2004-07-03 0:00:00   CS76522
# 3     Susamyr   42   73    Olivier Loudet  2004-07-04 0:00:00   CS76607
# 4      Djarly   43   74    Olivier Loudet  2004-07-07 0:00:00   CS76473
# ..        ...  ...  ...               ...                 ...       ...
# 226  Yeghegis   40   45        James Beck  1999-12-30 0:00:00   CS76394
# 227     Lerik   39   49        James Beck                 NaN   CS76388
# 228  Xanbulan   39   49        James Beck  1999-12-30 0:00:00   CS76387
# 229       NaN  NaN  NaN               NaN                 NaN       NaN
# 230       NaN  NaN  NaN               NaN                 NaN       NaN
#
#            admixture_group unknown       unknown2  in_pang23  in_pang69  \
# 0           western_europe     NaN     blu_circle      False      False
# 1                  admixed     NaN      forbidden      False      False
# 2                     asia     NaN  purple_circle      False       True
# 3                     asia     NaN  purple_circle      False       True
# 4                     asia     NaN  purple_circle      False      False
# ..                     ...     ...            ...        ...        ...
# 226                   asia     NaN  purple_circle      False      False
# 227  italy_balkan_caucasus     NaN     wht_circle      False      False
# 228  italy_balkan_caucasus     NaN     wht_circle      False      False
# 229                    NaN     NaN            NaN      False      False
# 230                    NaN     NaN            NaN      False      False
#
#      in_longreads
# 0            True
# 1           False
# 2            True
# 3            True
# 4           False
# ..            ...
# 226         False
# 227         False
# 228         False
# 229         False
# 230          True
#
# [231 rows x 18 columns]

# %%
import geopandas as gpd
import geodatasets
import matplotlib.pyplot as plt

# Load Natural Earth low-res world boundaries
world_path = geodatasets.get_path("naturalearth.land")
world = gpd.read_file(world_path)
# Out:
# Downloading file 'ne_110m_land.zip' from 'https://naciscdn.org/naturalearth/110m/physical/ne_110m_land.zip' to '/Users/tatiana/Library/Caches/geodatasets'.

# %%
gdf = gpd.GeoDataFrame(
    grenenet_accession,
    geometry=gpd.points_from_xy(
        grenenet_accession['lon'],
        grenenet_accession['lat']
    ),
    crs="EPSG:4326"
)

# %%
min_lon = grenenet_accession['lon'].min()
max_lon = grenenet_accession['lon'].max()
min_lat = grenenet_accession['lat'].min()
max_lat = grenenet_accession['lat'].max()

# Add 10% padding around each edge
lon_padding = (max_lon - min_lon) * 0.10
lat_padding = (max_lat - min_lat) * 0.10

xmin = min_lon - lon_padding
xmax = max_lon + lon_padding
ymin = min_lat - lat_padding
ymax = max_lat + lat_padding

import geopandas as gpd
import geodatasets
import matplotlib.pyplot as plt

# Load Natural Earth land polygons
world_path = geodatasets.get_path("naturalearth.land")
world = gpd.read_file(world_path)

# Convert your accessions to a GeoDataFrame
gdf = gpd.GeoDataFrame(
    grenenet_accession,
    geometry=gpd.points_from_xy(
        grenenet_accession['lon'],
        grenenet_accession['lat']
    ),
    crs="EPSG:4326"
)

# Bounding box
min_lon = gdf['lon'].min()
max_lon = gdf['lon'].max()
min_lat = gdf['lat'].min()
max_lat = gdf['lat'].max()

# Padding
lon_padding = (max_lon - min_lon) * 0.10
lat_padding = (max_lat - min_lat) * 0.10

xmin = min_lon - lon_padding
xmax = max_lon + lon_padding
ymin = min_lat - lat_padding
ymax = max_lat + lat_padding

# Plot
fig, ax = plt.subplots(figsize=(10,6))

# Plot land
world.plot(ax=ax, color="lightgrey", edgecolor="white")

# Plot accessions
gdf.plot(
    ax=ax,
    column='in_longreads',
    categorical=True,
    legend=True,
    cmap='bwr',     # or any palette you prefer
    markersize=30,
    alpha = 0.5
)

# Set zoom to bounding box
ax.set_xlim(xmin, xmax)
ax.set_ylim(ymin, ymax)


plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.title("GrENE-net Accessions Colored by Long-read Sequencing Status")
plt.show()

# %%
full_dt = grenenet_accession.merge(lr_1001, on = 'acc_ID', how = 'outer')

# %%
full_dt.columns
# Out:
# Index(['name_grene', 'country_grene', 'acc_ID', 'seq_by', 'name_1001',
#        'country_1001', 'name_2', 'lat', 'lon', 'collector', 'date',
#        'cs_number', 'admixture_group', 'unknown', 'unknown2', 'in_pang23',
#        'in_pang69', 'in_longreads', 'Assembly_ID', 'Accession_Name',
#        'Accession_alias', 'Original_Assembly_ID', 'Version', 'CSnumber',
#        'Latitude', 'Longitude', 'Altitude', 'Gaps', 'Sum', 'Largest',
#        'Pangenome_reference', 'Primary_Sequencing_Technology', 'Assembler',
#        'Individual_or_pool', 'Latest_released_Year', 'Published',
#        'Publication_First_author', 'Publication_year', 'Publication_Journal',
#        'Publication_DOI', 'Publication_URL', 'Best_unique_assembly'],
#       dtype='object')

# %%
# Prefer GrENE-net coords, fall back to long-read coords
full_dt['LAT'] = full_dt['lat'].fillna(full_dt['Latitude'])
full_dt['LON'] = full_dt['lon'].fillna(full_dt['Longitude'])

# %%
def classify(row):
    if row['in_longreads'] and not pd.isna(row['name_grene']):
        return 'both'
    elif row['in_longreads'] and pd.isna(row['name_grene']):
        return 'longread_only'
    elif (not row['in_longreads']) and not pd.isna(row['name_grene']):
        return 'grenenet'
    else:
        return 'other'

full_dt['dataset'] = full_dt.apply(classify, axis=1)

# %%
map_df = full_dt.dropna(subset=['LAT', 'LON'])

# %%
map_df['LON'].astype(float)
# Out:
# 1       4
# 2      -1
# 3     -73
# 6     -73
# 8      74
#        ..
# 569    -4
# 570    -5
# 571    -5
# 572    -8
# 573    -8
# Name: LON, Length: 414, dtype: float64

# %%
import geopandas as gpd
from geodatasets import get_path

gdf = gpd.GeoDataFrame(
    map_df,
    geometry=gpd.points_from_xy(map_df['LON'], map_df['LAT']),
    crs="EPSG:4326"
)

# %%
import geodatasets
world = gpd.read_file(get_path("naturalearth.land"))

# %%
import matplotlib.pyplot as plt

# Define custom colors for dataset categories
color_map = {
    'grenenet': 'blue',
    'longread_only': 'yellow',
    'both': 'green'
}

# Assign colors using the dataset column
gdf['color'] = gdf['dataset'].map(color_map)

fig, ax = plt.subplots(figsize=(15,10))

# Base map
world.plot(ax=ax, color="lightgrey", edgecolor="white")

# Plot the accessions
gdf.plot(
    ax=ax,
    color=gdf['color'],    # use custom colors
    markersize=30,

    alpha=0.6
)

# Add a manual legend
import matplotlib.patches as mpatches
legend_handles = [
    mpatches.Patch(color='blue', label='GrENE-net only'),
    mpatches.Patch(color='yellow', label='Long-read only'),
    mpatches.Patch(color='green', label='Both')
]
ax.legend(handles=legend_handles, title="Dataset")

# Zoom to bounding box
min_lon, max_lon = gdf['LON'].min(), gdf['LON'].max()
min_lat, max_lat = gdf['LAT'].min(), gdf['LAT'].max()

ax.set_xlim(min_lon - 2, max_lon + 2)
ax.set_ylim(min_lat - 2, max_lat + 2)

plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.title("GrENE-net Founders and Long-read Accessions")
plt.show()

# %%
## full ven diagram

# %%
pang_69 = pd.read_csv('69_ara_pang/accessions.csv', skiprows=2)
pang_23 = pd.read_csv('23_ara_pang/accessions.csv')

lr_1001 = pd.read_csv('long_read_seq_ara/Athaliana_assembly_IDs_OVERVIEW.csv', dtype=str)

grenenet = pd.read_csv('long_read_seq_ara/grene_ecotypes.csv')[['ID', 'name', 'country']]
grenenet = grenenet.dropna()
grenenet['acc_ID'] = grenenet['ID'].astype(int)

# %%
pang_69 = pang_69.rename(columns={'Accession': 'accession_name'})
pang_69['dataset_pang69'] = True

# %%
pang_23 = pang_23.rename(columns={'Name': 'accession_name'})
pang_23['dataset_pang23'] = True

# %%
grenenet = grenenet.rename(columns={'name': 'accession_name'})
grenenet['dataset_grenenet'] = True

# %%
## delete the F1 (Col-0/Cvi-0)
lr_1001 = lr_1001[lr_1001['Accession_Name'] != 'F1 (Col-0/Cvi-0)']

# %%
lr_1001 = lr_1001.rename(columns={
    'Accession_ID': 'acc_ID',
    'Accession_Name': 'accession_name'
})
lr_1001['acc_ID'] = lr_1001['acc_ID'].astype(str)
lr_1001['dataset_longread'] = True

lr_1001['acc_ID'] = lr_1001['acc_ID'].astype(int)

# %%
lr_1001['acc_ID'].astype(int)
# Out:
# 0      6909
# 1      6909
# 2      6909
# 3      7213
# 5      7213
#        ...
# 425    4840
# 426    5279
# 427    9133
# 428    9134
# 429    7417
# Name: acc_ID, Length: 429, dtype: int64

# %%
gr_lr = grenenet[['accession_name','acc_ID', 'dataset_grenenet' ]].merge(lr_1001[['accession_name','acc_ID', 'dataset_longread']], on = 'acc_ID', how = 'outer', suffixes=('_grene', '_lr'))

# %%
gr_lr = gr_lr.drop_duplicates()

# %%
gr_lr_pg23 = gr_lr.merge(pang_23[['accession_name', 'dataset_pang23']], left_on = 'accession_name_lr', right_on = 'accession_name', how = 'outer')

# %%
gr_lr_pg23_pg69 = gr_lr_pg23.merge(pang_69[['accession_name', 'dataset_pang69']], left_on = 'accession_name_lr', right_on = 'accession_name', how = 'outer')
## tehre are 8 that dont match ?

# %%
len(gr_lr_pg23_pg69)
# Out:
# 535

# %%
cols = ['dataset_grenenet','dataset_longread','dataset_pang23','dataset_pang69']

for c in cols:
    gr_lr_pg23_pg69[c] = gr_lr_pg23_pg69[c].fillna(False)
# Out:
# /var/folders/89/m0n7cpqn6153r2j98t2n5yq40000gr/T/ipykernel_99808/3840788534.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gr_lr_pg23_pg69[c] = gr_lr_pg23_pg69[c].fillna(False)

# %%
# Create sets by row index
setGRE = set(gr_lr_pg23_pg69.index[gr_lr_pg23_pg69['dataset_grenenet'] == True])
setLR  = set(gr_lr_pg23_pg69.index[gr_lr_pg23_pg69['dataset_longread'] == True])
set23  = set(gr_lr_pg23_pg69.index[gr_lr_pg23_pg69['dataset_pang23'] == True])
set69  = set(gr_lr_pg23_pg69.index[gr_lr_pg23_pg69['dataset_pang69'] == True])

# %%
from venny4py.venny4py import venny4py

sets = {
    "GrENE-net": setGRE,
    "Long-read": setLR,
    "Pangenome 23": set23,
    "Pangenome 69": set69
}

venny4py(
    sets,
)

# %%
lr_1001['acc_ID'].drop_duplicates()
# Out:
# 0      6909
# 3      7213
# 6      1741
# 8      6942
# 11     6898
#        ...
# 424    4857
# 425    4840
# 426    5279
# 427    9133
# 429    7417
# Name: acc_ID, Length: 355, dtype: int64
